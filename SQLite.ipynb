# %% [markdown]
# ###SQLite
#
# SQLite is an in-process library that implements a self-contained, serverless, zero-configuration, transactional SQL database engine. The code for SQLite is in the public domain and is thus free for use for any purpose, commercial or private. SQLite is the most widely deployed database in the world with more applications than we can count, including several high-profile projects.
#
# SQLite is an embedded SQL database engine. Unlike most other SQL databases, SQLite does not have a separate server process. SQLite reads and writes directly to ordinary disk files. A complete SQL database with multiple tables, indices, triggers, and views, is contained in a single disk file. The database file format is cross-platform - you can freely copy a database between 32-bit and 64-bit systems or between big-endian and little-endian architectures. These features make SQLite a popular choice as an Application File Format. Think of SQLite not as a replacement for Oracle but as a replacement for fopen()
#
# Because SQLite uses a very generic type system, we don't get the strict data types that we would in most other databases (such as MySQL and PostgreSQL); therefore, all of our data is going to be stored as text. In other databases, we'd store dates as a date or datetime field but in SQLite it's text.
#
# http://www.thegeekstuff.com/2012/09/sqlite-command-examples/

# %%
import pandas as pd
import sqlite3

# Create a SQL connection to our SQLite database
#con = sqlite3.connect(r'C:\Users\Sterling7\Dropbox\dave45678\Python for Data Analytics\sqlite3\Chinook_Sqlite.sqlite')
con = sqlite3.connect(r'sqlite3\movielens')
cur = con.cursor()

# the result of a "cursor.execute" can be iterated over by row
for row in cur.execute('SELECT * FROM Movies;'):
    print(row)
# Out:
# (1, 'Toy Story (1995)', '1995-01-01')
# (2, 'GoldenEye (1995)', '1995-01-01')
# (3, 'Four Rooms (1995)', '1995-01-01')
# (4, 'Get Shorty (1995)', '1995-01-01')
# (5, 'Copycat (1995)', '1995-01-01')
# (6, 'Shanghai Triad (Yao a yao yao dao waipo qiao) (1995)', '1995-01-01')
# (7, 'Twelve Monkeys (1995)', '1995-01-01')
# (8, 'Babe (1995)', '1995-01-01')
# (9, 'Dead Man Walking (1995)', '1995-01-01')
# (10, 'Richard III (1995)', '1996-01-22')
# (11, 'Seven (Se7en) (1995)', '1995-01-01')
# (12, 'Usual Suspects, The (1995)', '1995-08-14')
# (13, 'Mighty Aphrodite (1995)', '1995-10-30')
# (14, 'Postino, Il (1994)', '1994-01-01')
# (15, "Mr. Holland's Opus (1995)", '1996-01-29')
# (16, 'French Twist (Gazon maudit) (1995)', '1995-01-01')
# (17, 'From Dusk Till Dawn (1996)', '1996-02-05')
# (18, 'White Balloon, The (1995)', '1995-01-01')
# (19, "Antonia's Line (1995)", '1995-01-01')
# (20, 'Angels and Insects (1995)', '1995-01-01')
# (21, 'Muppet Treasure Island (1996)', '1996-02-16')
# (22, 'Braveheart (1995)', '1996-02-16')
# (23, 'Taxi Driver (1976)', '1996-02-16')
# (24, 'Rumble in the Bronx (1995)', '1996-02-23')
# (25, 'Birdcage, The (1996)', '1996-03-08')
# (26, 'Brothers McMullen, The (1995)', '1995-01-01')
# (27, 'Bad Boys (1995)', '1995-01-01')
# (28, 'Apollo 13 (1995)', '1995-01-01')
# (29, 'Batman Forever (1995)', '1995-01-01')
# (30, 'Belle de jour (1967)', '1967-01-01')
# (31, 'Crimson Tide (1995)', '1995-01-01')
# (32, 'Crumb (1994)', '1994-01-01')
# (33, 'Desperado (1995)', '1995-01-01')
# (34, 'Doom Generation, The (1995)', '1995-01-01')
# (35, 'Free Willy 2: The Adventure Home (1995)', '1995-01-01')
# (36, 'Mad Love (1995)', '1995-01-01')
# (37, 'Nadja (1994)', '1994-01-01')
# (38, 'Net, The (1995)', '1995-01-01')
# (39, 'Strange Days (1995)', '1995-01-01')
# (40, 'To Wong Foo, Thanks for Everything! Julie Newmar (1995)', '1995-01-01')
# (41, 'Billy Madison (1995)', '1995-01-01')
# (42, 'Clerks (1994)', '1994-01-01')
# (43, 'Disclosure (1994)', '1994-01-01')
# (44, 'Dolores Claiborne (1994)', '1994-01-01')
# (45, 'Eat Drink Man Woman (1994)', '1994-01-01')
# (46, 'Exotica (1994)', '1994-01-01')
# (47, 'Ed Wood (1994)', '1994-01-01')
# (48, 'Hoop Dreams (1994)', '1994-01-01')
# (49, 'I.Q. (1994)', '1994-01-01')
# (50, 'Star Wars (1977)', '1977-01-01')
# (51, 'Legends of the Fall (1994)', '1994-01-01')
# (52, 'Madness of King George, The (1994)', '1994-01-01')
# (53, 'Natural Born Killers (1994)', '1994-01-01')
# (54, 'Outbreak (1995)', '1995-01-01')
# (55, 'Professional, The (1994)', '1994-01-01')
# (56, 'Pulp Fiction (1994)', '1994-01-01')
# (57, 'Priest (1994)', '1994-01-01')
# (58, 'Quiz Show (1994)', '1994-01-01')
# (59, 'Three Colors: Red (1994)', '1994-01-01')
# (60, 'Three Colors: Blue (1993)', '1993-01-01')
# (61, 'Three Colors: White (1994)', '1994-01-01')
# (62, 'Stargate (1994)', '1994-01-01')
# (63, 'Santa Clause, The (1994)', '1994-01-01')
# (64, 'Shawshank Redemption, The (1994)', '1994-01-01')
# (65, "What's Eating Gilbert Grape (1993)", '1993-01-01')
# (66, 'While You Were Sleeping (1995)', '1995-01-01')
# (67, 'Ace Ventura: Pet Detective (1994)', '1994-01-01')
# (68, 'Crow, The (1994)', '1994-01-01')
# (69, 'Forrest Gump (1994)', '1994-01-01')
# (70, 'Four Weddings and a Funeral (1994)', '1994-01-01')
# (71, 'Lion King, The (1994)', '1994-01-01')
# (72, 'Mask, The (1994)', '1994-01-01')
# (73, 'Maverick (1994)', '1994-01-01')
# (74, 'Faster Pussycat! Kill! Kill! (1965)', '1965-01-01')
# (75, 'Brother Minister: The Assassination of Malcolm X (1994)', '1994-01-01')
# (76, "Carlito's Way (1993)", '1993-01-01')
# (77, 'Firm, The (1993)', '1993-01-01')
# (78, 'Free Willy (1993)', '1993-01-01')
# (79, 'Fugitive, The (1993)', '1993-01-01')
# (80, 'Hot Shots! Part Deux (1993)', '1993-01-01')
# (81, 'Hudsucker Proxy, The (1994)', '1994-01-01')
# (82, 'Jurassic Park (1993)', '1993-01-01')
# (83, 'Much Ado About Nothing (1993)', '1993-01-01')
# (84, "Robert A. Heinlein's The Puppet Masters (1994)", '1994-01-01')
# (85, 'Ref, The (1994)', '1994-01-01')
# (86, 'Remains of the Day, The (1993)', '1993-01-01')
# (87, 'Searching for Bobby Fischer (1993)', '1993-01-01')
# (88, 'Sleepless in Seattle (1993)', '1993-01-01')
# (89, 'Blade Runner (1982)', '1982-01-01')
# (90, 'So I Married an Axe Murderer (1993)', '1993-01-01')
# (91, 'Nightmare Before Christmas, The (1993)', '1993-01-01')
# (92, 'True Romance (1993)', '1993-01-01')
# (93, 'Welcome to the Dollhouse (1995)', '1996-05-24')
# (94, 'Home Alone (1990)', '1990-01-01')
# (95, 'Aladdin (1992)', '1992-01-01')
# (96, 'Terminator 2: Judgment Day (1991)', '1991-01-01')
# (97, 'Dances with Wolves (1990)', '1990-01-01')
# (98, 'Silence of the Lambs, The (1991)', '1991-01-01')
# (99, 'Snow White and the Seven Dwarfs (1937)', '1937-01-01')
# (100, 'Fargo (1996)', '1997-02-14')
# (101, 'Heavy Metal (1981)', '1981-03-08')
# (102, 'Aristocats, The (1970)', '1970-01-01')
# (103, 'All Dogs Go to Heaven 2 (1996)', '1996-03-29')
# (104, 'Theodore Rex (1995)', '1996-03-29')
# (105, 'Sgt. Bilko (1996)', '1996-03-29')
# (106, 'Diabolique (1996)', '1996-01-01')
# (107, 'Moll Flanders (1996)', '1996-06-14')
# (108, 'Kids in the Hall: Brain Candy (1996)', '1996-04-12')
# (109, 'Mystery Science Theater 3000: The Movie (1996)', '1996-04-19')
# (110, 'Operation Dumbo Drop (1995)', '1995-01-01')
# (111, 'Truth About Cats & Dogs, The (1996)', '1996-04-26')
# (112, 'Flipper (1996)', '1996-05-10')
# (113, 'Horseman on the Roof, The (Hussard sur le toit, Le) (1995)', '1996-04-19')
# (114, 'Wallace & Gromit: The Best of Aardman Animation (1996)', '1996-04-05')
# (115, 'Haunted World of Edward D. Wood Jr., The (1995)', '1996-04-26')
# (116, 'Cold Comfort Farm (1995)', '1996-04-23')
# (117, 'Rock, The (1996)', '1996-06-07')
# (118, 'Twister (1996)', '1996-05-10')
# (119, 'Maya Lin: A Strong Clear Vision (1994)', '1994-01-01')
# (120, 'Striptease (1996)', '1996-06-28')
# (121, 'Independence Day (ID4) (1996)', '1996-07-03')
# (122, 'Cable Guy, The (1996)', '1996-06-14')
# (123, 'Frighteners, The (1996)', '1996-07-19')
# (124, 'Lone Star (1996)', '1996-06-21')
# (125, 'Phenomenon (1996)', '1996-06-29')
# (126, 'Spitfire Grill, The (1996)', '1996-09-06')
# (127, 'Godfather, The (1972)', '1972-01-01')
# (128, 'Supercop (1992)', '1996-07-26')
# (129, 'Bound (1996)', '1996-10-04')
# (130, 'Kansas City (1996)', '1996-08-16')
# (131, "Breakfast at Tiffany's (1961)", '1961-01-01')
# (132, 'Wizard of Oz, The (1939)', '1939-01-01')
# (133, 'Gone with the Wind (1939)', '1939-01-01')
# (134, 'Citizen Kane (1941)', '1941-01-01')
# (135, '2001: A Space Odyssey (1968)', '1968-01-01')
# (136, 'Mr. Smith Goes to Washington (1939)', '1939-01-01')
# (137, 'Big Night (1996)', '1996-09-20')
# (138, 'D3: The Mighty Ducks (1996)', '1996-10-04')
# (139, 'Love Bug, The (1969)', '1969-01-01')
# (140, 'Homeward Bound: The Incredible Journey (1993)', '1993-01-01')
# (141, '20,000 Leagues Under the Sea (1954)', '1954-01-01')
# (142, 'Bedknobs and Broomsticks (1971)', '1971-01-01')
# (143, 'Sound of Music, The (1965)', '1965-01-01')
# (144, 'Die Hard (1988)', '1988-01-01')
# (145, 'Lawnmower Man, The (1992)', '1992-01-01')
# (146, 'Unhook the Stars (1996)', '1996-10-30')
# (147, 'Long Kiss Goodnight, The (1996)', '1996-10-05')
# (148, 'Ghost and the Darkness, The (1996)', '1996-10-11')
# (149, 'Jude (1996)', '1996-11-01')
# (150, 'Swingers (1996)', '1996-10-18')
# (151, 'Willy Wonka and the Chocolate Factory (1971)', '1971-01-01')
# (152, 'Sleeper (1973)', '1973-01-01')
# (153, 'Fish Called Wanda, A (1988)', '1988-01-01')
# (154, "Monty Python's Life of Brian (1979)", '1979-01-01')
# (155, 'Dirty Dancing (1987)', '1987-01-01')
# (156, 'Reservoir Dogs (1992)', '1992-01-01')
# (157, 'Platoon (1986)', '1986-01-01')
# (158, "Weekend at Bernie's (1989)", '1989-01-01')
# (159, 'Basic Instinct (1992)', '1992-01-01')
# (160, 'Glengarry Glen Ross (1992)', '1992-01-01')
# (161, 'Top Gun (1986)', '1986-01-01')
# (162, 'On Golden Pond (1981)', '1981-01-01')
# (163, 'Return of the Pink Panther, The (1974)', '1974-01-01')
# (164, 'Abyss, The (1989)', '1989-01-01')
# (165, 'Jean de Florette (1986)', '1986-01-01')
# (166, 'Manon of the Spring (Manon des sources) (1986)', '1986-01-01')
# (167, 'Private Benjamin (1980)', '1980-01-01')
# (168, 'Monty Python and the Holy Grail (1974)', '1974-01-01')
# (169, 'Wrong Trousers, The (1993)', '1993-01-01')
# (170, 'Cinema Paradiso (1988)', '1988-01-01')
# (171, 'Delicatessen (1991)', '1991-01-01')
# (172, 'Empire Strikes Back, The (1980)', '1980-01-01')
# (173, 'Princess Bride, The (1987)', '1987-01-01')
# (174, 'Raiders of the Lost Ark (1981)', '1981-01-01')
# (175, 'Brazil (1985)', '1985-01-01')
# (176, 'Aliens (1986)', '1986-01-01')
# (177, 'Good, The Bad and The Ugly, The (1966)', '1966-01-01')
# (178, '12 Angry Men (1957)', '1957-01-01')
# (179, 'Clockwork Orange, A (1971)', '1971-01-01')
# (180, 'Apocalypse Now (1979)', '1979-01-01')
# (181, 'Return of the Jedi (1983)', '1997-03-14')
# (182, 'GoodFellas (1990)', '1990-01-01')
# (183, 'Alien (1979)', '1979-01-01')
# (184, 'Army of Darkness (1993)', '1993-01-01')
# (185, 'Psycho (1960)', '1960-01-01')
# (186, 'Blues Brothers, The (1980)', '1980-01-01')
# (187, 'Godfather: Part II, The (1974)', '1974-01-01')
# (188, 'Full Metal Jacket (1987)', '1987-01-01')
# (189, 'Grand Day Out, A (1992)', '1992-01-01')
# (190, 'Henry V (1989)', '1989-01-01')
# (191, 'Amadeus (1984)', '1984-01-01')
# (192, 'Raging Bull (1980)', '1980-01-01')
# (193, 'Right Stuff, The (1983)', '1983-01-01')
# (194, 'Sting, The (1973)', '1973-01-01')
# (195, 'Terminator, The (1984)', '1984-01-01')
# (196, 'Dead Poets Society (1989)', '1989-01-01')
# (197, 'Graduate, The (1967)', '1967-01-01')
# (198, 'Nikita (La Femme Nikita) (1990)', '1990-01-01')
# (199, 'Bridge on the River Kwai, The (1957)', '1957-01-01')
# (200, 'Shining, The (1980)', '1980-01-01')
# (201, 'Evil Dead II (1987)', '1987-01-01')
# (202, 'Groundhog Day (1993)', '1993-01-01')
# (203, 'Unforgiven (1992)', '1992-01-01')
# (204, 'Back to the Future (1985)', '1985-01-01')
# (205, 'Patton (1970)', '1970-01-01')
# (206, 'Akira (1988)', '1988-01-01')
# (207, 'Cyrano de Bergerac (1990)', '1990-01-01')
# (208, 'Young Frankenstein (1974)', '1974-01-01')
# (209, 'This Is Spinal Tap (1984)', '1984-01-01')
# (210, 'Indiana Jones and the Last Crusade (1989)', '1989-01-01')
# (211, 'M*A*S*H (1970)', '1970-01-01')
# (212, 'Unbearable Lightness of Being, The (1988)', '1988-01-01')
# (213, 'Room with a View, A (1986)', '1986-01-01')
# (214, 'Pink Floyd - The Wall (1982)', '1982-01-01')
# (215, 'Field of Dreams (1989)', '1989-01-01')
# (216, 'When Harry Met Sally... (1989)', '1989-01-01')
# (217, "Bram Stoker's Dracula (1992)", '1992-01-01')
# (218, 'Cape Fear (1991)', '1991-01-01')
# (219, 'Nightmare on Elm Street, A (1984)', '1984-01-01')
# (220, 'Mirror Has Two Faces, The (1996)', '1996-11-15')
# (221, 'Breaking the Waves (1996)', '1996-11-15')
# (222, 'Star Trek: First Contact (1996)', '1996-11-22')
# (223, 'Sling Blade (1996)', '1996-11-22')
# (224, 'Ridicule (1996)', '1996-11-27')
# (225, '101 Dalmatians (1996)', '1996-11-27')
# (226, 'Die Hard 2 (1990)', '1990-01-01')
# (227, 'Star Trek VI: The Undiscovered Country (1991)', '1991-01-01')
# (228, 'Star Trek: The Wrath of Khan (1982)', '1982-01-01')
# (229, 'Star Trek III: The Search for Spock (1984)', '1984-01-01')
# (230, 'Star Trek IV: The Voyage Home (1986)', '1986-01-01')
# (231, 'Batman Returns (1992)', '1992-01-01')
# (232, 'Young Guns (1988)', '1988-01-01')
# (233, 'Under Siege (1992)', '1992-01-01')
# (234, 'Jaws (1975)', '1975-01-01')
# (235, 'Mars Attacks! (1996)', '1996-12-13')
# (236, 'Citizen Ruth (1996)', '1996-12-13')
# (237, 'Jerry Maguire (1996)', '1996-12-13')
# (238, 'Raising Arizona (1987)', '1987-01-01')
# (239, 'Sneakers (1992)', '1992-01-01')
# (240, 'Beavis and Butt-head Do America (1996)', '1996-12-20')
# (241, 'Last of the Mohicans, The (1992)', '1992-01-01')
# (242, 'Kolya (1996)', '1997-01-24')
# (243, 'Jungle2Jungle (1997)', '1997-03-07')
# (244, "Smilla's Sense of Snow (1997)", '1997-03-14')
# (245, "Devil's Own, The (1997)", '1997-03-26')
# (246, 'Chasing Amy (1997)', '1997-01-01')
# (247, 'Turbo: A Power Rangers Movie (1997)', '1997-03-28')
# (248, 'Grosse Pointe Blank (1997)', '1997-04-11')
# (249, 'Austin Powers: International Man of Mystery (1997)', '1997-05-02')
# (250, 'Fifth Element, The (1997)', '1997-05-09')
# (251, 'Shall We Dance? (1996)', '1997-07-11')
# (252, 'Lost World: Jurassic Park, The (1997)', '1997-05-23')
# (253, 'Pillow Book, The (1995)', '1997-06-13')
# (254, 'Batman & Robin (1997)', '1997-06-20')
# (255, "My Best Friend's Wedding (1997)", '1997-06-20')
# (256, 'When the Cats Away (Chacun cherche son chat) (1996)', '1997-06-20')
# (257, 'Men in Black (1997)', '1997-07-04')
# (258, 'Contact (1997)', '1997-07-11')
# (259, 'George of the Jungle (1997)', '1997-01-01')
# (260, 'Event Horizon (1997)', '1997-01-01')
# (261, 'Air Bud (1997)', '1997-08-01')
# (262, 'In the Company of Men (1997)', '1997-08-01')
# (263, 'Steel (1997)', '1997-08-15')
# (264, 'Mimic (1997)', '1997-08-22')
# (265, 'Hunt for Red October, The (1990)', '1990-01-01')
# (266, 'Kull the Conqueror (1997)', '1997-08-29')
# (267, 'unknown', None)
# (268, 'Chasing Amy (1997)', '1997-01-01')
# (269, 'Full Monty, The (1997)', '1997-01-01')
# (270, 'Gattaca (1997)', '1997-01-01')
# (271, 'Starship Troopers (1997)', '1997-01-01')
# (272, 'Good Will Hunting (1997)', '1997-01-01')
# (273, 'Heat (1995)', '1995-01-01')
# (274, 'Sabrina (1995)', '1995-01-01')
# (275, 'Sense and Sensibility (1995)', '1995-01-01')
# (276, 'Leaving Las Vegas (1995)', '1995-01-01')
# (277, 'Restoration (1995)', '1995-01-01')
# (278, 'Bed of Roses (1996)', '1996-01-01')
# (279, 'Once Upon a Time... When We Were Colored (1995)', '1995-01-01')
# (280, 'Up Close and Personal (1996)', '1996-03-01')
# (281, 'River Wild, The (1994)', '1994-01-01')
# (282, 'Time to Kill, A (1996)', '1996-07-13')
# (283, 'Emma (1996)', '1996-08-02')
# (284, 'Tin Cup (1996)', '1996-08-16')
# (285, 'Secrets & Lies (1996)', '1996-10-04')
# (286, 'English Patient, The (1996)', '1996-11-15')
# (287, "Marvin's Room (1996)", '1996-12-18')
# (288, 'Scream (1996)', '1996-12-20')
# (289, 'Evita (1996)', '1996-12-25')
# (290, 'Fierce Creatures (1997)', '1997-01-10')
# (291, 'Absolute Power (1997)', '1997-02-14')
# (292, 'Rosewood (1997)', '1997-02-21')
# (293, 'Donnie Brasco (1997)', '1997-02-28')
# (294, 'Liar Liar (1997)', '1997-03-21')
# (295, 'Breakdown (1997)', '1997-05-02')
# (296, 'Promesse, La (1996)', '1997-05-16')
# (297, "Ulee's Gold (1997)", '1997-01-01')
# (298, 'Face/Off (1997)', '1997-06-27')
# (299, 'Hoodlum (1997)', '1997-08-22')
# (300, 'Air Force One (1997)', '1997-01-01')
# (301, 'In & Out (1997)', '1997-09-19')
# (302, 'L.A. Confidential (1997)', '1997-01-01')
# (303, "Ulee's Gold (1997)", '1997-01-01')
# (304, 'Fly Away Home (1996)', '1996-09-13')
# (305, 'Ice Storm, The (1997)', '1997-01-01')
# (306, 'Mrs. Brown (Her Majesty, Mrs. Brown) (1997)', '1997-01-01')
# (307, "Devil's Advocate, The (1997)", '1997-01-01')
# (308, 'FairyTale: A True Story (1997)', '1997-01-01')
# (309, 'Deceiver (1997)', '1997-01-01')
# (310, 'Rainmaker, The (1997)', '1997-01-01')
# (311, 'Wings of the Dove, The (1997)', '1997-01-01')
# (312, 'Midnight in the Garden of Good and Evil (1997)', '1997-01-01')
# (313, 'Titanic (1997)', '1997-01-01')
# (314, '3 Ninjas: High Noon At Mega Mountain (1998)', '1997-01-01')
# (315, 'Apt Pupil (1998)', '1998-10-23')
# (316, 'As Good As It Gets (1997)', '1997-12-23')
# (317, 'In the Name of the Father (1993)', '1993-01-01')
# (318, "Schindler's List (1993)", '1993-01-01')
# (319, 'Everyone Says I Love You (1996)', '1996-12-06')
# (320, 'Paradise Lost: The Child Murders at Robin Hood Hills (1996)', '1996-12-06')
# (321, 'Mother (1996)', '1996-12-25')
# (322, 'Murder at 1600 (1997)', '1997-04-18')
# (323, "Dante's Peak (1997)", '1997-02-07')
# (324, 'Lost Highway (1997)', '1997-02-21')
# (325, 'Crash (1996)', '1997-03-21')
# (326, 'G.I. Jane (1997)', '1997-01-01')
# (327, 'Cop Land (1997)', '1997-01-01')
# (328, 'Conspiracy Theory (1997)', '1997-08-08')
# (329, 'Desperate Measures (1998)', '1998-01-30')
# (330, '187 (1997)', '1997-01-01')
# (331, 'Edge, The (1997)', '1997-09-26')
# (332, 'Kiss the Girls (1997)', '1997-01-01')
# (333, 'Game, The (1997)', '1997-01-01')
# (334, 'U Turn (1997)', '1997-01-01')
# (335, 'How to Be a Player (1997)', '1997-01-01')
# (336, 'Playing God (1997)', '1997-01-01')
# (337, 'House of Yes, The (1997)', '1997-01-01')
# (338, 'Bean (1997)', '1997-01-01')
# (339, 'Mad City (1997)', '1997-01-01')
# (340, 'Boogie Nights (1997)', '1997-01-01')
# (341, 'Critical Care (1997)', '1997-01-01')
# (342, 'Man Who Knew Too Little, The (1997)', '1997-01-01')
# (343, 'Alien: Resurrection (1997)', '1997-01-01')
# (344, 'Apostle, The (1997)', '1997-12-18')
# (345, 'Deconstructing Harry (1997)', '1997-01-01')
# (346, 'Jackie Brown (1997)', '1997-01-01')
# (347, 'Wag the Dog (1997)', '1998-01-09')
# (348, 'Desperate Measures (1998)', '1998-01-30')
# (349, 'Hard Rain (1998)', '1998-01-16')
# (350, 'Fallen (1998)', '1998-01-16')
# (351, 'Prophecy II, The (1998)', '1998-01-16')
# (352, 'Spice World (1997)', '1997-01-01')
# (353, 'Deep Rising (1998)', '1998-01-30')
# (354, 'Wedding Singer, The (1998)', '1998-02-13')
# (355, 'Sphere (1998)', '1998-02-13')
# (356, 'Client, The (1994)', '1994-01-01')
# (357, "One Flew Over the Cuckoo's Nest (1975)", '1975-01-01')
# (358, 'Spawn (1997)', '1997-08-01')
# (359, 'Assignment, The (1997)', '1997-01-01')
# (360, 'Wonderland (1997)', '1997-01-01')
# (361, 'Incognito (1997)', '1997-01-01')
# (362, 'Blues Brothers 2000 (1998)', '1998-02-06')
# (363, 'Sudden Death (1995)', '1995-01-01')
# (364, 'Ace Ventura: When Nature Calls (1995)', '1995-01-01')
# (365, 'Powder (1995)', '1995-01-01')
# (366, 'Dangerous Minds (1995)', '1995-01-01')
# (367, 'Clueless (1995)', '1995-01-01')
# (368, 'Bio-Dome (1996)', '1996-01-01')
# (369, 'Black Sheep (1996)', '1996-02-02')
# (370, 'Mary Reilly (1996)', '1996-02-23')
# (371, 'Bridges of Madison County, The (1995)', '1996-02-09')
# (372, 'Jeffrey (1995)', '1995-01-01')
# (373, 'Judge Dredd (1995)', '1995-01-01')
# (374, 'Mighty Morphin Power Rangers: The Movie (1995)', '1995-01-01')
# (375, 'Showgirls (1995)', '1995-01-01')
# (376, 'Houseguest (1994)', '1994-01-01')
# (377, 'Heavyweights (1994)', '1994-01-01')
# (378, 'Miracle on 34th Street (1994)', '1994-01-01')
# (379, 'Tales From the Crypt Presents: Demon Knight (1995)', '1995-01-01')
# (380, 'Star Trek: Generations (1994)', '1994-01-01')
# (381, "Muriel's Wedding (1994)", '1994-01-01')
# (382, 'Adventures of Priscilla, Queen of the Desert, The (1994)', '1994-01-01')
# (383, 'Flintstones, The (1994)', '1994-01-01')
# (384, 'Naked Gun 33 1/3: The Final Insult (1994)', '1994-01-01')
# (385, 'True Lies (1994)', '1994-01-01')
# (386, 'Addams Family Values (1993)', '1993-01-01')
# (387, 'Age of Innocence, The (1993)', '1993-01-01')
# (388, 'Beverly Hills Cop III (1994)', '1994-01-01')
# (389, 'Black Beauty (1994)', '1994-01-01')
# (390, 'Fear of a Black Hat (1993)', '1993-01-01')
# (391, 'Last Action Hero (1993)', '1993-01-01')
# (392, 'Man Without a Face, The (1993)', '1993-01-01')
# (393, 'Mrs. Doubtfire (1993)', '1993-01-01')
# (394, 'Radioland Murders (1994)', '1994-01-01')
# (395, 'Robin Hood: Men in Tights (1993)', '1993-01-01')
# (396, 'Serial Mom (1994)', '1994-01-01')
# (397, 'Striking Distance (1993)', '1993-01-01')
# (398, 'Super Mario Bros. (1993)', '1993-01-01')
# (399, 'Three Musketeers, The (1993)', '1993-01-01')
# (400, 'Little Rascals, The (1994)', '1994-01-01')
# (401, 'Brady Bunch Movie, The (1995)', '1995-01-01')
# (402, 'Ghost (1990)', '1990-01-01')
# (403, 'Batman (1989)', '1989-01-01')
# (404, 'Pinocchio (1940)', '1940-01-01')
# (405, 'Mission: Impossible (1996)', '1996-05-22')
# (406, 'Thinner (1996)', '1996-10-25')
# (407, 'Spy Hard (1996)', '1996-05-24')
# (408, 'Close Shave, A (1995)', '1996-04-28')
# (409, 'Jack (1996)', '1996-08-07')
# (410, 'Kingpin (1996)', '1996-07-12')
# (411, 'Nutty Professor, The (1996)', '1996-06-28')
# (412, 'Very Brady Sequel, A (1996)', '1996-08-23')
# (413, 'Tales from the Crypt Presents: Bordello of Blood (1996)', '1996-07-19')
# (414, 'My Favorite Year (1982)', '1982-01-01')
# (415, 'Apple Dumpling Gang, The (1975)', '1975-01-01')
# (416, 'Old Yeller (1957)', '1957-01-01')
# (417, 'Parent Trap, The (1961)', '1961-01-01')
# (418, 'Cinderella (1950)', '1950-01-01')
# (419, 'Mary Poppins (1964)', '1964-01-01')
# (420, 'Alice in Wonderland (1951)', '1951-01-01')
# (421, "William Shakespeare's Romeo and Juliet (1996)", '1996-10-25')
# (422, 'Aladdin and the King of Thieves (1996)', '1996-01-01')
# (423, 'E.T. the Extra-Terrestrial (1982)', '1982-01-01')
# (424, 'Children of the Corn: The Gathering (1996)', '1996-01-01')
# (425, 'Bob Roberts (1992)', '1992-01-01')
# (426, 'Transformers: The Movie, The (1986)', '1986-01-01')
# (427, 'To Kill a Mockingbird (1962)', '1962-01-01')
# (428, 'Harold and Maude (1971)', '1971-01-01')
# (429, 'Day the Earth Stood Still, The (1951)', '1951-01-01')
# (430, 'Duck Soup (1933)', '1933-01-01')
# (431, 'Highlander (1986)', '1986-01-01')
# (432, 'Fantasia (1940)', '1940-01-01')
# (433, 'Heathers (1989)', '1989-01-01')
# (434, 'Forbidden Planet (1956)', '1956-01-01')
# (435, 'Butch Cassidy and the Sundance Kid (1969)', '1969-01-01')
# (436, 'American Werewolf in London, An (1981)', '1981-01-01')
# (437, "Amityville 1992: It's About Time (1992)", '1992-01-01')
# (438, 'Amityville 3-D (1983)', '1983-01-01')
# (439, 'Amityville: A New Generation (1993)', '1993-01-01')
# (440, 'Amityville II: The Possession (1982)', '1982-01-01')
# (441, 'Amityville Horror, The (1979)', '1979-01-01')
# (442, 'Amityville Curse, The (1990)', '1990-01-01')
# (443, 'Birds, The (1963)', '1963-01-01')
# (444, 'Blob, The (1958)', '1958-01-01')
# (445, 'Body Snatcher, The (1945)', '1945-01-01')
# (446, 'Burnt Offerings (1976)', '1976-01-01')
# (447, 'Carrie (1976)', '1976-01-01')
# (448, 'Omen, The (1976)', '1976-01-01')
# (449, 'Star Trek: The Motion Picture (1979)', '1979-01-01')
# (450, 'Star Trek V: The Final Frontier (1989)', '1989-01-01')
# (451, 'Grease (1978)', '1978-01-01')
# (452, 'Jaws 2 (1978)', '1978-01-01')
# (453, 'Jaws 3-D (1983)', '1983-01-01')
# (454, 'Bastard Out of Carolina (1996)', '1996-12-15')
# (455, "Jackie Chan's First Strike (1996)", '1997-01-10')
# (456, 'Beverly Hills Ninja (1997)', '1997-01-17')
# (457, 'Free Willy 3: The Rescue (1997)', '1997-08-08')
# (458, 'Nixon (1995)', '1995-01-01')
# (459, 'Cry, the Beloved Country (1995)', '1995-01-01')
# (460, 'Crossing Guard, The (1995)', '1995-01-01')
# (461, 'Smoke (1995)', '1995-01-01')
# (462, 'Like Water For Chocolate (Como agua para chocolate) (1992)', '1992-01-01')
# (463, 'Secret of Roan Inish, The (1994)', '1994-01-01')
# (464, 'Vanya on 42nd Street (1994)', '1994-01-01')
# (465, 'Jungle Book, The (1994)', '1994-01-01')
# (466, 'Red Rock West (1992)', '1992-01-01')
# (467, 'Bronx Tale, A (1993)', '1993-01-01')
# (468, 'Rudy (1993)', '1993-01-01')
# (469, 'Short Cuts (1993)', '1993-01-01')
# (470, 'Tombstone (1993)', '1993-01-01')
# (471, 'Courage Under Fire (1996)', '1996-03-08')
# (472, 'Dragonheart (1996)', '1996-05-31')
# (473, 'James and the Giant Peach (1996)', '1996-04-12')
# (474, 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1963)', '1963-01-01')
# (475, 'Trainspotting (1996)', '1996-07-19')
# (476, 'First Wives Club, The (1996)', '1996-09-14')
# (477, 'Matilda (1996)', '1996-08-02')
# (478, 'Philadelphia Story, The (1940)', '1940-01-01')
# (479, 'Vertigo (1958)', '1958-01-01')
# (480, 'North by Northwest (1959)', '1959-01-01')
# (481, 'Apartment, The (1960)', '1960-01-01')
# (482, 'Some Like It Hot (1959)', '1959-01-01')
# (483, 'Casablanca (1942)', '1942-01-01')
# (484, 'Maltese Falcon, The (1941)', '1941-01-01')
# (485, 'My Fair Lady (1964)', '1964-01-01')
# (486, 'Sabrina (1954)', '1954-01-01')
# (487, 'Roman Holiday (1953)', '1953-01-01')
# (488, 'Sunset Blvd. (1950)', '1950-01-01')
# (489, 'Notorious (1946)', '1946-01-01')
# (490, 'To Catch a Thief (1955)', '1955-01-01')
# (491, 'Adventures of Robin Hood, The (1938)', '1938-01-01')
# (492, 'East of Eden (1955)', '1955-01-01')
# (493, 'Thin Man, The (1934)', '1934-01-01')
# (494, 'His Girl Friday (1940)', '1940-01-01')
# (495, 'Around the World in 80 Days (1956)', '1956-01-01')
# (496, "It's a Wonderful Life (1946)", '1946-01-01')
# (497, 'Bringing Up Baby (1938)', '1938-01-01')
# (498, 'African Queen, The (1951)', '1951-01-01')
# (499, 'Cat on a Hot Tin Roof (1958)', '1958-01-01')
# (500, 'Fly Away Home (1996)', '1996-09-13')
# (501, 'Dumbo (1941)', '1941-01-01')
# (502, 'Bananas (1971)', '1971-01-01')
# (503, 'Candidate, The (1972)', '1972-01-01')
# (504, 'Bonnie and Clyde (1967)', '1967-01-01')
# (505, 'Dial M for Murder (1954)', '1954-01-01')
# (506, 'Rebel Without a Cause (1955)', '1955-01-01')
# (507, 'Streetcar Named Desire, A (1951)', '1951-01-01')
# (508, 'People vs. Larry Flynt, The (1996)', '1996-12-27')
# (509, 'My Left Foot (1989)', '1989-01-01')
# (510, 'Magnificent Seven, The (1954)', '1954-01-01')
# (511, 'Lawrence of Arabia (1962)', '1962-01-01')
# (512, 'Wings of Desire (1987)', '1987-01-01')
# (513, 'Third Man, The (1949)', '1949-01-01')
# (514, 'Annie Hall (1977)', '1977-01-01')
# (515, 'Boot, Das (1981)', '1997-04-04')
# (516, 'Local Hero (1983)', '1983-01-01')
# (517, 'Manhattan (1979)', '1979-01-01')
# (518, "Miller's Crossing (1990)", '1990-01-01')
# (519, 'Treasure of the Sierra Madre, The (1948)', '1948-01-01')
# (520, 'Great Escape, The (1963)', '1963-01-01')
# (521, 'Deer Hunter, The (1978)', '1978-01-01')
# (522, 'Down by Law (1986)', '1986-01-01')
# (523, 'Cool Hand Luke (1967)', '1967-01-01')
# (524, 'Great Dictator, The (1940)', '1940-01-01')
# (525, 'Big Sleep, The (1946)', '1946-01-01')
# (526, 'Ben-Hur (1959)', '1959-01-01')
# (527, 'Gandhi (1982)', '1982-01-01')
# (528, 'Killing Fields, The (1984)', '1984-01-01')
# (529, 'My Life as a Dog (Mitt liv som hund) (1985)', '1985-01-01')
# (530, 'Man Who Would Be King, The (1975)', '1975-01-01')
# (531, 'Shine (1996)', '1996-11-22')
# (532, 'Kama Sutra: A Tale of Love (1996)', '1997-03-07')
# (533, 'Daytrippers, The (1996)', '1997-03-21')
# (534, 'Traveller (1997)', '1997-04-18')
# (535, 'Addicted to Love (1997)', '1997-05-23')
# (536, 'Ponette (1996)', '1997-05-23')
# (537, 'My Own Private Idaho (1991)', '1991-01-01')
# (538, 'Anastasia (1997)', '1997-01-01')
# (539, 'Mouse Hunt (1997)', '1997-01-01')
# (540, 'Money Train (1995)', '1995-01-01')
# (541, 'Mortal Kombat (1995)', '1995-01-01')
# (542, 'Pocahontas (1995)', '1995-01-01')
# (543, 'Misйrables, Les (1995)', '1995-01-01')
# (544, "Things to Do in Denver when You're Dead (1995)", '1996-02-02')
# (545, 'Vampire in Brooklyn (1995)', '1995-01-01')
# (546, 'Broken Arrow (1996)', '1996-02-09')
# (547, "Young Poisoner's Handbook, The (1995)", '1996-02-23')
# (548, 'NeverEnding Story III, The (1994)', '1996-02-02')
# (549, 'Rob Roy (1995)', '1995-01-01')
# (550, 'Die Hard: With a Vengeance (1995)', '1995-01-01')
# (551, 'Lord of Illusions (1995)', '1995-01-01')
# (552, 'Species (1995)', '1995-01-01')
# (553, 'Walk in the Clouds, A (1995)', '1995-01-01')
# (554, 'Waterworld (1995)', '1995-01-01')
# (555, "White Man's Burden (1995)", '1995-01-01')
# (556, 'Wild Bill (1995)', '1995-01-01')
# (557, 'Farinelli: il castrato (1994)', '1994-01-01')
# (558, 'Heavenly Creatures (1994)', '1994-01-01')
# (559, 'Interview with the Vampire (1994)', '1994-01-01')
# (560, "Kid in King Arthur's Court, A (1995)", '1995-01-01')
# (561, "Mary Shelley's Frankenstein (1994)", '1994-01-01')
# (562, 'Quick and the Dead, The (1995)', '1995-01-01')
# (563, "Stephen King's The Langoliers (1995)", '1995-01-01')
# (564, 'Tales from the Hood (1995)', '1995-01-01')
# (565, 'Village of the Damned (1995)', '1995-01-01')
# (566, 'Clear and Present Danger (1994)', '1994-01-01')
# (567, "Wes Craven's New Nightmare (1994)", '1994-01-01')
# (568, 'Speed (1994)', '1994-01-01')
# (569, 'Wolf (1994)', '1994-01-01')
# (570, 'Wyatt Earp (1994)', '1994-01-01')
# (571, 'Another Stakeout (1993)', '1993-01-01')
# (572, 'Blown Away (1994)', '1994-01-01')
# (573, 'Body Snatchers (1993)', '1993-01-01')
# (574, 'Boxing Helena (1993)', '1993-01-01')
# (575, "City Slickers II: The Legend of Curly's Gold (1994)", '1994-01-01')
# (576, 'Cliffhanger (1993)', '1993-01-01')
# (577, 'Coneheads (1993)', '1993-01-01')
# (578, 'Demolition Man (1993)', '1993-01-01')
# (579, 'Fatal Instinct (1993)', '1993-01-01')
# (580, 'Englishman Who Went Up a Hill, But Came Down a Mountain, The (1995)', '1995-01-01')
# (581, 'Kalifornia (1993)', '1993-01-01')
# (582, 'Piano, The (1993)', '1993-01-01')
# (583, 'Romeo Is Bleeding (1993)', '1993-01-01')
# (584, 'Secret Garden, The (1993)', '1993-01-01')
# (585, 'Son in Law (1993)', '1993-01-01')
# (586, 'Terminal Velocity (1994)', '1994-01-01')
# (587, 'Hour of the Pig, The (1993)', '1993-01-01')
# (588, 'Beauty and the Beast (1991)', '1991-01-01')
# (589, 'Wild Bunch, The (1969)', '1969-01-01')
# (590, 'Hellraiser: Bloodline (1996)', '1996-03-08')
# (591, 'Primal Fear (1996)', '1996-03-30')
# (592, 'True Crime (1995)', '1995-01-01')
# (593, 'Stalingrad (1993)', '1993-01-01')
# (594, 'Heavy (1995)', '1996-06-05')
# (595, 'Fan, The (1996)', '1996-08-16')
# (596, 'Hunchback of Notre Dame, The (1996)', '1996-06-21')
# (597, 'Eraser (1996)', '1996-06-21')
# (598, 'Big Squeeze, The (1996)', '1996-09-06')
# (599, 'Police Story 4: Project S (Chao ji ji hua) (1993)', '1996-08-16')
# (600, "Daniel Defoe's Robinson Crusoe (1996)", '1996-01-01')
# (601, 'For Whom the Bell Tolls (1943)', '1943-01-01')
# (602, 'American in Paris, An (1951)', '1951-01-01')
# (603, 'Rear Window (1954)', '1954-01-01')
# (604, 'It Happened One Night (1934)', '1934-01-01')
# (605, 'Meet Me in St. Louis (1944)', '1944-01-01')
# (606, 'All About Eve (1950)', '1950-01-01')
# (607, 'Rebecca (1940)', '1940-01-01')
# (608, 'Spellbound (1945)', '1945-01-01')
# (609, 'Father of the Bride (1950)', '1950-01-01')
# (610, 'Gigi (1958)', '1958-01-01')
# (611, 'Laura (1944)', '1944-01-01')
# (612, 'Lost Horizon (1937)', '1937-01-01')
# (613, 'My Man Godfrey (1936)', '1936-01-01')
# (614, 'Giant (1956)', '1956-01-01')
# (615, '39 Steps, The (1935)', '1935-01-01')
# (616, 'Night of the Living Dead (1968)', '1968-01-01')
# (617, 'Blue Angel, The (Blaue Engel, Der) (1930)', '1930-01-01')
# (618, 'Picnic (1955)', '1955-01-01')
# (619, 'Extreme Measures (1996)', '1996-09-27')
# (620, 'Chamber, The (1996)', '1996-10-11')
# (621, 'Davy Crockett, King of the Wild Frontier (1955)', '1955-01-01')
# (622, 'Swiss Family Robinson (1960)', '1960-01-01')
# (623, 'Angels in the Outfield (1994)', '1994-01-01')
# (624, 'Three Caballeros, The (1945)', '1945-01-01')
# (625, 'Sword in the Stone, The (1963)', '1963-01-01')
# (626, 'So Dear to My Heart (1949)', '1949-01-01')
# (627, 'Robin Hood: Prince of Thieves (1991)', '1991-01-01')
# (628, 'Sleepers (1996)', '1996-10-18')
# (629, 'Victor/Victoria (1982)', '1982-01-01')
# (630, 'Great Race, The (1965)', '1965-01-01')
# (631, 'Crying Game, The (1992)', '1992-01-01')
# (632, "Sophie's Choice (1982)", '1982-01-01')
# (633, 'Christmas Carol, A (1938)', '1938-01-01')
# (634, "Microcosmos: Le peuple de l'herbe (1996)", '1996-10-11')
# (635, 'Fog, The (1980)', '1980-01-01')
# (636, 'Escape from New York (1981)', '1981-01-01')
# (637, 'Howling, The (1981)', '1981-01-01')
# (638, 'Return of Martin Guerre, The (Retour de Martin Guerre, Le) (1982)', '1982-01-01')
# (639, 'Tin Drum, The (Blechtrommel, Die) (1979)', '1979-01-01')
# (640, 'Cook the Thief His Wife & Her Lover, The (1989)', '1989-01-01')
# (641, 'Paths of Glory (1957)', '1957-01-01')
# (642, 'Grifters, The (1990)', '1990-01-01')
# (643, 'The Innocent (1994)', '1994-01-01')
# (644, 'Thin Blue Line, The (1988)', '1988-01-01')
# (645, 'Paris Is Burning (1990)', '1990-01-01')
# (646, 'Once Upon a Time in the West (1969)', '1969-01-01')
# (647, 'Ran (1985)', '1985-01-01')
# (648, 'Quiet Man, The (1952)', '1952-01-01')
# (649, 'Once Upon a Time in America (1984)', '1984-01-01')
# (650, 'Seventh Seal, The (Sjunde inseglet, Det) (1957)', '1957-01-01')
# (651, 'Glory (1989)', '1989-01-01')
# (652, 'Rosencrantz and Guildenstern Are Dead (1990)', '1990-01-01')
# (653, 'Touch of Evil (1958)', '1958-01-01')
# (654, 'Chinatown (1974)', '1974-01-01')
# (655, 'Stand by Me (1986)', '1986-01-01')
# (656, 'M (1931)', '1931-01-01')
# (657, 'Manchurian Candidate, The (1962)', '1962-01-01')
# (658, 'Pump Up the Volume (1990)', '1990-01-01')
# (659, 'Arsenic and Old Lace (1944)', '1944-01-01')
# (660, 'Fried Green Tomatoes (1991)', '1991-01-01')
# (661, 'High Noon (1952)', '1952-01-01')
# (662, 'Somewhere in Time (1980)', '1980-01-01')
# (663, 'Being There (1979)', '1979-01-01')
# (664, 'Paris, Texas (1984)', '1984-01-01')
# (665, 'Alien 3 (1992)', '1992-01-01')
# (666, "Blood For Dracula (Andy Warhol's Dracula) (1974)", '1974-01-01')
# (667, 'Audrey Rose (1977)', '1977-01-01')
# (668, 'Blood Beach (1981)', '1981-01-01')
# (669, 'Body Parts (1991)', '1991-01-01')
# (670, 'Body Snatchers (1993)', '1993-01-01')
# (671, 'Bride of Frankenstein (1935)', '1935-01-01')
# (672, 'Candyman (1992)', '1992-01-01')
# (673, 'Cape Fear (1962)', '1962-01-01')
# (674, 'Cat People (1982)', '1982-01-01')
# (675, 'Nosferatu (Nosferatu, eine Symphonie des Grauens) (1922)', '1922-01-01')
# (676, 'Crucible, The (1996)', '1996-11-27')
# (677, 'Fire on the Mountain (1996)', '1997-01-24')
# (678, 'Volcano (1997)', '1997-04-25')
# (679, 'Conan the Barbarian (1981)', '1981-01-01')
# (680, 'Kull the Conqueror (1997)', '1997-08-29')
# (681, 'Wishmaster (1997)', '1997-01-01')
# (682, 'I Know What You Did Last Summer (1997)', '1997-10-17')
# (683, 'Rocket Man (1997)', '1997-01-01')
# (684, 'In the Line of Fire (1993)', '1993-01-01')
# (685, 'Executive Decision (1996)', '1996-03-09')
# (686, 'Perfect World, A (1993)', '1993-01-01')
# (687, "McHale's Navy (1997)", '1997-04-18')
# (688, 'Leave It to Beaver (1997)', '1997-08-22')
# (689, 'Jackal, The (1997)', '1997-01-01')
# (690, 'Seven Years in Tibet (1997)', '1997-01-01')
# (691, 'Dark City (1998)', '1998-01-09')
# (692, 'American President, The (1995)', '1995-01-01')
# (693, 'Casino (1995)', '1995-01-01')
# (694, 'Persuasion (1995)', '1995-09-25')
# (695, 'Kicking and Screaming (1995)', '1995-01-01')
# (696, 'City Hall (1996)', '1996-02-16')
# (697, 'Basketball Diaries, The (1995)', '1995-01-01')
# (698, 'Browning Version, The (1994)', '1994-01-01')
# (699, 'Little Women (1994)', '1994-01-01')
# (700, 'Miami Rhapsody (1995)', '1995-01-01')
# (701, 'Wonderful, Horrible Life of Leni Riefenstahl, The (1993)', '1993-01-01')
# (702, 'Barcelona (1994)', '1994-01-01')
# (703, "Widows' Peak (1994)", '1994-01-01')
# (704, 'House of the Spirits, The (1993)', '1993-01-01')
# (705, "Singin' in the Rain (1952)", '1952-01-01')
# (706, 'Bad Moon (1996)', '1996-11-01')
# (707, 'Enchanted April (1991)', '1991-01-01')
# (708, 'Sex, Lies, and Videotape (1989)', '1989-01-01')
# (709, 'Strictly Ballroom (1992)', '1992-01-01')
# (710, 'Better Off Dead... (1985)', '1985-01-01')
# (711, 'Substance of Fire, The (1996)', '1996-12-06')
# (712, 'Tin Men (1987)', '1987-01-01')
# (713, 'Othello (1995)', '1995-12-18')
# (714, 'Carrington (1995)', '1995-01-01')
# (715, 'To Die For (1995)', '1995-01-01')
# (716, 'Home for the Holidays (1995)', '1995-01-01')
# (717, 'Juror, The (1996)', '1996-01-01')
# (718, 'In the Bleak Midwinter (1995)', '1996-02-23')
# (719, 'Canadian Bacon (1994)', '1994-01-01')
# (720, 'First Knight (1995)', '1995-01-01')
# (721, 'Mallrats (1995)', '1995-01-01')
# (722, 'Nine Months (1995)', '1995-01-01')
# (723, 'Boys on the Side (1995)', '1995-01-01')
# (724, 'Circle of Friends (1995)', '1995-01-01')
# (725, 'Exit to Eden (1994)', '1994-01-01')
# (726, 'Fluke (1995)', '1995-01-01')
# (727, 'Immortal Beloved (1994)', '1994-01-01')
# (728, 'Junior (1994)', '1994-01-01')
# (729, 'Nell (1994)', '1994-01-01')
# (730, 'Queen Margot (Reine Margot, La) (1994)', '1996-01-01')
# (731, 'Corrina, Corrina (1994)', '1994-01-01')
# (732, 'Dave (1993)', '1993-01-01')
# (733, 'Go Fish (1994)', '1994-01-01')
# (734, 'Made in America (1993)', '1993-01-01')
# (735, 'Philadelphia (1993)', '1993-01-01')
# (736, 'Shadowlands (1993)', '1993-01-01')
# (737, 'Sirens (1994)', '1994-01-01')
# (738, 'Threesome (1994)', '1994-01-01')
# (739, 'Pretty Woman (1990)', '1990-01-01')
# (740, 'Jane Eyre (1996)', '1996-04-05')
# (741, 'Last Supper, The (1995)', '1996-04-05')
# (742, 'Ransom (1996)', '1996-11-08')
# (743, 'Crow: City of Angels, The (1996)', '1996-08-30')
# (744, 'Michael Collins (1996)', '1996-10-11')
# (745, 'Ruling Class, The (1972)', '1972-01-01')
# (746, 'Real Genius (1985)', '1985-01-01')
# (747, 'Benny & Joon (1993)', '1993-01-01')
# (748, 'Saint, The (1997)', '1997-03-14')
# (749, 'MatchMaker, The (1997)', '1997-01-01')
# (750, 'Amistad (1997)', '1997-12-18')
# (751, 'Tomorrow Never Dies (1997)', '1997-01-01')
# (752, 'Replacement Killers, The (1998)', '1998-02-06')
# (753, 'Burnt By the Sun (1994)', '1994-01-01')
# (754, 'Red Corner (1997)', '1997-01-01')
# (755, 'Jumanji (1995)', '1995-01-01')
# (756, 'Father of the Bride Part II (1995)', '1995-01-01')
# (757, 'Across the Sea of Time (1995)', '1995-01-01')
# (758, 'Lawnmower Man 2: Beyond Cyberspace (1996)', '1996-01-01')
# (759, 'Fair Game (1995)', '1995-01-01')
# (760, 'Screamers (1995)', '1995-01-01')
# (761, 'Nick of Time (1995)', '1995-01-01')
# (762, 'Beautiful Girls (1996)', '1996-02-09')
# (763, 'Happy Gilmore (1996)', '1996-02-16')
# (764, 'If Lucy Fell (1996)', '1996-03-08')
# (765, 'Boomerang (1992)', '1992-01-01')
# (766, 'Man of the Year (1995)', '1996-03-01')
# (767, 'Addiction, The (1995)', '1995-01-01')
# (768, 'Casper (1995)', '1995-01-01')
# (769, 'Congo (1995)', '1995-01-01')
# (770, 'Devil in a Blue Dress (1995)', '1995-01-01')
# (771, 'Johnny Mnemonic (1995)', '1995-01-01')
# (772, 'Kids (1995)', '1995-01-01')
# (773, 'Mute Witness (1994)', '1994-01-01')
# (774, 'Prophecy, The (1995)', '1995-01-01')
# (775, 'Something to Talk About (1995)', '1995-01-01')
# (776, 'Three Wishes (1995)', '1995-01-01')
# (777, 'Castle Freak (1995)', '1995-01-01')
# (778, 'Don Juan DeMarco (1995)', '1995-01-01')
# (779, 'Drop Zone (1994)', '1994-01-01')
# (780, 'Dumb & Dumber (1994)', '1994-01-01')
# (781, 'French Kiss (1995)', '1995-01-01')
# (782, 'Little Odessa (1994)', '1994-01-01')
# (783, 'Milk Money (1994)', '1994-01-01')
# (784, 'Beyond Bedlam (1993)', '1993-01-01')
# (785, 'Only You (1994)', '1994-01-01')
# (786, 'Perez Family, The (1995)', '1995-01-01')
# (787, 'Roommates (1995)', '1995-01-01')
# (788, 'Relative Fear (1994)', '1994-01-01')
# (789, 'Swimming with Sharks (1995)', '1995-01-01')
# (790, 'Tommy Boy (1995)', '1995-01-01')
# (791, 'Baby-Sitters Club, The (1995)', '1995-01-01')
# (792, 'Bullets Over Broadway (1994)', '1994-01-01')
# (793, 'Crooklyn (1994)', '1994-01-01')
# (794, 'It Could Happen to You (1994)', '1994-01-01')
# (795, 'Richie Rich (1994)', '1994-01-01')
# (796, 'Speechless (1994)', '1994-01-01')
# (797, 'Timecop (1994)', '1994-01-01')
# (798, 'Bad Company (1995)', '1995-01-01')
# (799, 'Boys Life (1995)', '1995-01-01')
# (800, 'In the Mouth of Madness (1995)', '1995-01-01')
# (801, 'Air Up There, The (1994)', '1994-01-01')
# (802, 'Hard Target (1993)', '1993-01-01')
# (803, 'Heaven & Earth (1993)', '1993-01-01')
# (804, 'Jimmy Hollywood (1994)', '1994-01-01')
# (805, 'Manhattan Murder Mystery (1993)', '1993-01-01')
# (806, 'Menace II Society (1993)', '1993-01-01')
# (807, 'Poetic Justice (1993)', '1993-01-01')
# (808, 'Program, The (1993)', '1993-01-01')
# (809, 'Rising Sun (1993)', '1993-01-01')
# (810, 'Shadow, The (1994)', '1994-01-01')
# (811, 'Thirty-Two Short Films About Glenn Gould (1993)', '1993-01-01')
# (812, 'Andre (1994)', '1994-01-01')
# (813, 'Celluloid Closet, The (1995)', '1996-03-15')
# (814, 'Great Day in Harlem, A (1994)', '1994-01-01')
# (815, 'One Fine Day (1996)', '1996-11-30')
# (816, 'Candyman: Farewell to the Flesh (1995)', '1995-01-01')
# (817, 'Frisk (1995)', '1996-03-29')
# (818, 'Girl 6 (1996)', '1996-03-22')
# (819, 'Eddie (1996)', '1996-05-31')
# (820, 'Space Jam (1996)', '1996-11-15')
# (821, 'Mrs. Winterbourne (1996)', '1996-04-19')
# (822, 'Faces (1968)', '1968-01-01')
# (823, 'Mulholland Falls (1996)', '1996-04-26')
# (824, 'Great White Hype, The (1996)', '1996-05-03')
# (825, 'Arrival, The (1996)', '1996-05-31')
# (826, 'Phantom, The (1996)', '1996-06-07')
# (827, 'Daylight (1996)', '1996-12-06')
# (828, 'Alaska (1996)', '1996-08-21')
# (829, 'Fled (1996)', '1996-07-19')
# (830, 'Power 98 (1995)', '1996-05-17')
# (831, 'Escape from L.A. (1996)', '1996-08-09')
# (832, 'Bogus (1996)', '1996-09-06')
# (833, 'Bulletproof (1996)', '1996-09-06')
# (834, 'Halloween: The Curse of Michael Myers (1995)', '1995-01-01')
# (835, 'Gay Divorcee, The (1934)', '1934-01-01')
# (836, 'Ninotchka (1939)', '1939-01-01')
# (837, 'Meet John Doe (1941)', '1941-01-01')
# (838, 'In the Line of Duty 2 (1987)', '1996-08-30')
# (839, 'Loch Ness (1995)', '1995-01-01')
# (840, 'Last Man Standing (1996)', '1996-09-20')
# (841, 'Glimmer Man, The (1996)', '1996-10-04')
# (842, 'Pollyanna (1960)', '1960-01-01')
# (843, 'Shaggy Dog, The (1959)', '1959-01-01')
# (844, 'Freeway (1996)', '1996-08-23')
# (845, 'That Thing You Do! (1996)', '1996-09-28')
# (846, 'To Gillian on Her 37th Birthday (1996)', '1996-10-18')
# (847, 'Looking for Richard (1996)', '1996-10-11')
# (848, 'Murder, My Sweet (1944)', '1944-01-01')
# (849, 'Days of Thunder (1990)', '1990-01-01')
# (850, 'Perfect Candidate, A (1996)', '1996-09-27')
# (851, 'Two or Three Things I Know About Her (1966)', '1966-01-01')
# (852, 'Bloody Child, The (1996)', '1996-10-26')
# (853, 'Braindead (1992)', '1992-01-01')
# (854, 'Bad Taste (1987)', '1987-01-01')
# (855, 'Diva (1981)', '1981-01-01')
# (856, 'Night on Earth (1991)', '1991-01-01')
# (857, 'Paris Was a Woman (1995)', '1996-11-08')
# (858, 'Amityville: Dollhouse (1996)', '1996-01-01')
# (859, "April Fool's Day (1986)", '1986-01-01')
# (860, 'Believers, The (1987)', '1987-01-01')
# (861, 'Nosferatu a Venezia (1986)', '1986-01-01')
# (862, 'Jingle All the Way (1996)', '1996-11-22')
# (863, 'Garden of Finzi-Contini, The (Giardino dei Finzi-Contini, Il) (1970)', '1996-11-08')
# (864, 'My Fellow Americans (1996)', '1996-12-20')
# (865, 'Ice Storm, The (1997)', '1997-01-01')
# (866, 'Michael (1996)', '1996-12-25')
# (867, 'Whole Wide World, The (1996)', '1996-12-25')
# (868, 'Hearts and Minds (1996)', '1997-01-10')
# (869, 'Fools Rush In (1997)', '1997-02-14')
# (870, 'Touch (1997)', '1997-02-14')
# (871, 'Vegas Vacation (1997)', '1997-02-14')
# (872, 'Love Jones (1997)', '1997-03-14')
# (873, 'Picture Perfect (1997)', '1997-08-01')
# (874, 'Career Girls (1997)', '1997-08-08')
# (875, "She's So Lovely (1997)", '1997-08-22')
# (876, 'Money Talks (1997)', '1997-08-22')
# (877, 'Excess Baggage (1997)', '1997-01-01')
# (878, 'That Darn Cat! (1997)', '1997-02-14')
# (879, 'Peacemaker, The (1997)', '1997-01-01')
# (880, 'Soul Food (1997)', '1997-01-01')
# (881, 'Money Talks (1997)', '1997-08-22')
# (882, 'Washington Square (1997)', '1997-01-01')
# (883, 'Telling Lies in America (1997)', '1997-01-01')
# (884, 'Year of the Horse (1997)', '1997-01-01')
# (885, 'Phantoms (1998)', '1998-01-01')
# (886, 'Life Less Ordinary, A (1997)', '1997-01-01')
# (887, "Eve's Bayou (1997)", '1997-01-01')
# (888, 'One Night Stand (1997)', '1997-01-01')
# (889, 'Tango Lesson, The (1997)', '1997-01-01')
# (890, 'Mortal Kombat: Annihilation (1997)', '1997-01-01')
# (891, 'Bent (1997)', '1997-12-18')
# (892, 'Flubber (1997)', '1997-01-01')
# (893, 'For Richer or Poorer (1997)', '1997-01-01')
# (894, 'Home Alone 3 (1997)', '1997-01-01')
# (895, 'Scream 2 (1997)', '1997-01-01')
# (896, 'Sweet Hereafter, The (1997)', '1997-01-01')
# (897, 'Time Tracers (1995)', '1995-01-01')
# (898, 'Postman, The (1997)', '1997-01-01')
# (899, 'Winter Guest, The (1997)', '1997-01-01')
# (900, 'Kundun (1997)', '1997-12-25')
# (901, 'Mr. Magoo (1997)', '1997-12-25')
# (902, 'Big Lebowski, The (1998)', '1997-12-26')
# (903, 'Afterglow (1997)', '1997-12-26')
# (904, 'Ma vie en rose (My Life in Pink) (1997)', '1997-12-26')
# (905, 'Great Expectations (1998)', '1998-01-01')
# (906, 'Oscar & Lucinda (1997)', '1997-12-31')
# (907, 'Vermin (1998)', '1997-01-01')
# (908, 'Half Baked (1998)', '1998-01-16')
# (909, 'Dangerous Beauty (1998)', '1998-01-23')
# (910, 'Nil By Mouth (1997)', '1998-02-06')
# (911, 'Twilight (1998)', '1998-01-30')
# (912, 'U.S. Marshalls (1998)', '1998-03-10')
# (913, 'Love and Death on Long Island (1997)', '1998-03-10')
# (914, 'Wild Things (1998)', '1998-03-14')
# (915, 'Primary Colors (1998)', '1998-03-20')
# (916, 'Lost in Space (1998)', '1998-03-27')
# (917, 'Mercury Rising (1998)', '1998-03-27')
# (918, 'City of Angels (1998)', '1998-04-03')
# (919, 'City of Lost Children, The (1995)', '1995-01-01')
# (920, 'Two Bits (1995)', '1995-01-01')
# (921, 'Farewell My Concubine (1993)', '1993-01-01')
# (922, 'Dead Man (1995)', '1996-05-10')
# (923, 'Raise the Red Lantern (1991)', '1991-01-01')
# (924, 'White Squall (1996)', '1996-01-01')
# (925, 'Unforgettable (1996)', '1996-02-23')
# (926, 'Down Periscope (1996)', '1996-03-01')
# (927, 'Flower of My Secret, The (Flor de mi secreto, La) (1995)', '1996-03-08')
# (928, 'Craft, The (1996)', '1996-04-26')
# (929, 'Harriet the Spy (1996)', '1996-07-03')
# (930, 'Chain Reaction (1996)', '1996-07-31')
# (931, 'Island of Dr. Moreau, The (1996)', '1996-08-23')
# (932, 'First Kid (1996)', '1996-08-30')
# (933, 'Funeral, The (1996)', '1996-10-25')
# (934, "Preacher's Wife, The (1996)", '1996-12-13')
# (935, 'Paradise Road (1997)', '1997-04-18')
# (936, 'Brassed Off (1996)', '1997-06-13')
# (937, 'Thousand Acres, A (1997)', '1997-01-01')
# (938, 'Smile Like Yours, A (1997)', '1997-01-01')
# (939, 'Murder in the First (1995)', '1995-01-01')
# (940, 'Airheads (1994)', '1994-01-01')
# (941, 'With Honors (1994)', '1994-01-01')
# (942, "What's Love Got to Do with It (1993)", '1993-01-01')
# (943, 'Killing Zoe (1994)', '1994-01-01')
# (944, 'Renaissance Man (1994)', '1994-01-01')
# (945, 'Charade (1963)', '1963-01-01')
# (946, 'Fox and the Hound, The (1981)', '1981-01-01')
# (947, 'Big Blue, The (Grand bleu, Le) (1988)', '1988-01-01')
# (948, 'Booty Call (1997)', '1997-02-28')
# (949, 'How to Make an American Quilt (1995)', '1995-01-01')
# (950, 'Georgia (1995)', '1995-01-01')
# (951, 'Indian in the Cupboard, The (1995)', '1995-01-01')
# (952, 'Blue in the Face (1995)', '1995-01-01')
# (953, 'Unstrung Heroes (1995)', '1995-01-01')
# (954, 'Unzipped (1995)', '1995-01-01')
# (955, 'Before Sunrise (1995)', '1995-01-01')
# (956, "Nobody's Fool (1994)", '1994-01-01')
# (957, 'Pushing Hands (1992)', '1992-01-01')
# (958, 'To Live (Huozhe) (1994)', '1994-01-01')
# (959, 'Dazed and Confused (1993)', '1993-01-01')
# (960, 'Naked (1993)', '1993-01-01')
# (961, 'Orlando (1993)', '1993-01-01')
# (962, 'Ruby in Paradise (1993)', '1993-01-01')
# (963, 'Some Folks Call It a Sling Blade (1993)', '1993-01-01')
# (964, 'Month by the Lake, A (1995)', '1995-01-01')
# (965, 'Funny Face (1957)', '1957-01-01')
# (966, 'Affair to Remember, An (1957)', '1957-01-01')
# (967, 'Little Lord Fauntleroy (1936)', '1936-01-01')
# (968, 'Inspector General, The (1949)', '1949-01-01')
# (969, 'Winnie the Pooh and the Blustery Day (1968)', '1968-01-01')
# (970, 'Hear My Song (1991)', '1991-01-01')
# (971, 'Mediterraneo (1991)', '1991-01-01')
# (972, 'Passion Fish (1992)', '1992-01-01')
# (973, 'Grateful Dead (1995)', '1996-10-18')
# (974, 'Eye for an Eye (1996)', '1996-01-01')
# (975, 'Fear (1996)', '1996-04-12')
# (976, 'Solo (1996)', '1996-08-23')
# (977, 'Substitute, The (1996)', '1996-04-19')
# (978, "Heaven's Prisoners (1996)", '1996-05-10')
# (979, 'Trigger Effect, The (1996)', '1996-08-30')
# (980, 'Mother Night (1996)', '1996-11-01')
# (981, 'Dangerous Ground (1997)', '1996-09-04')
# (982, 'Maximum Risk (1996)', '1996-09-13')
# (983, "Rich Man's Wife, The (1996)", '1996-09-13')
# (984, 'Shadow Conspiracy (1997)', '1997-01-31')
# (985, 'Blood & Wine (1997)', '1996-11-15')
# (986, 'Turbulence (1997)', '1997-01-10')
# (987, 'Underworld (1997)', '1997-05-09')
# (988, 'Beautician and the Beast, The (1997)', '1997-02-07')
# (989, "Cats Don't Dance (1997)", '1997-03-26')
# (990, 'Anna Karenina (1997)', '1997-04-04')
# (991, 'Keys to Tulsa (1997)', '1997-04-11')
# (992, 'Head Above Water (1996)', '1997-06-20')
# (993, 'Hercules (1997)', '1997-06-27')
# (994, 'Last Time I Committed Suicide, The (1997)', '1997-06-20')
# (995, 'Kiss Me, Guido (1997)', '1997-01-01')
# (996, 'Big Green, The (1995)', '1995-01-01')
# (997, 'Stuart Saves His Family (1995)', '1995-01-01')
# (998, 'Cabin Boy (1994)', '1994-01-01')
# (999, 'Clean Slate (1994)', '1994-01-01')
# (1000, 'Lightning Jack (1994)', '1994-01-01')
# (1001, 'Stupids, The (1996)', '1996-08-30')
# (1002, 'Pest, The (1997)', '1997-02-07')
# (1003, 'That Darn Cat! (1997)', '1997-02-14')
# (1004, 'Geronimo: An American Legend (1993)', '1993-01-01')
# (1005, 'Double vie de Vйronique, La (Double Life of Veronique, The) (1991)', '1991-01-01')
# (1006, 'Until the End of the World (Bis ans Ende der Welt) (1991)', '1991-01-01')
# (1007, 'Waiting for Guffman (1996)', '1997-01-31')
# (1008, 'I Shot Andy Warhol (1996)', '1996-05-01')
# (1009, 'Stealing Beauty (1996)', '1996-06-14')
# (1010, 'Basquiat (1996)', '1996-08-16')
# (1011, '2 Days in the Valley (1996)', '1996-09-27')
# (1012, 'Private Parts (1997)', '1997-03-07')
# (1013, 'Anaconda (1997)', '1997-04-11')
# (1014, "Romy and Michele's High School Reunion (1997)", '1997-04-25')
# (1015, 'Shiloh (1997)', '1997-05-23')
# ...
# (1355, 'Infinity (1996)', '1996-10-04')
# (1356, "Ed's Next Move (1996)", '1996-10-04')
# (1357, 'For the Moment (1994)', '1994-01-01')
# (1358, 'The Deadly Cure (1996)', '1996-09-16')
# (1359, 'Boys in Venice (1996)', '1996-09-24')
# (1360, 'Sexual Life of the Belgians, The (1994)', '1994-01-01')
# (1361, 'Search for One-eye Jimmy, The (1996)', '1996-01-01')
# (1362, 'American Strays (1996)', '1996-09-13')
# (1363, 'Leopard Son, The (1996)', '1996-09-27')
# (1364, 'Bird of Prey (1996)', '1996-10-04')
# (1365, 'Johnny 100 Pesos (1993)', '1993-01-01')
# (1366, 'JLG/JLG - autoportrait de dйcembre (1994)', '1994-01-01')
# (1367, 'Faust (1994)', '1994-01-01')
# (1368, 'Mina Tannenbaum (1994)', '1994-01-01')
# (1369, 'Forbidden Christ, The (Cristo proibito, Il) (1950)', '1950-01-01')
# (1370, "I Can't Sleep (J'ai pas sommeil) (1994)", '1994-01-01')
# (1371, 'Machine, The (1994)', '1994-01-01')
# (1372, 'Stranger, The (1994)', '1994-01-01')
# (1373, 'Good Morning (1971)', '1971-02-04')
# (1374, 'Falling in Love Again (1980)', '1980-01-01')
# (1375, 'Cement Garden, The (1993)', '1993-01-01')
# (1376, 'Meet Wally Sparks (1997)', '1997-01-31')
# (1377, 'Hotel de Love (1996)', '1997-02-07')
# (1378, 'Rhyme & Reason (1997)', '1997-03-05')
# (1379, 'Love and Other Catastrophes (1996)', '1997-03-28')
# (1380, 'Hollow Reed (1996)', '1997-05-02')
# (1381, 'Losing Chase (1996)', '1996-01-01')
# (1382, 'Bonheur, Le (1965)', '1997-05-16')
# (1383, 'Second Jungle Book: Mowgli & Baloo, The (1997)', '1997-05-16')
# (1384, 'Squeeze (1996)', '1997-06-13')
# (1385, "Roseanna's Grave (For Roseanna) (1997)", '1997-06-20')
# (1386, 'Tetsuo II: Body Hammer (1992)', '1997-06-20')
# (1387, 'Fall (1997)', '1997-06-27')
# (1388, 'Gabbeh (1996)', '1997-06-27')
# (1389, 'Mondo (1996)', '1997-06-27')
# (1390, 'Innocent Sleep, The (1995)', '1997-06-27')
# (1391, 'For Ever Mozart (1996)', '1997-07-04')
# (1392, 'Locusts, The (1997)', '1997-01-01')
# (1393, 'Stag (1997)', '1997-01-01')
# (1394, 'Swept from the Sea (1997)', '1997-01-01')
# (1395, 'Hurricane Streets (1998)', '1998-01-01')
# (1396, 'Stonewall (1995)', '1996-07-26')
# (1397, 'Of Human Bondage (1934)', '1934-01-01')
# (1398, 'Anna (1996)', '1996-11-13')
# (1399, 'Stranger in the House (1997)', '1997-01-01')
# (1400, 'Picture Bride (1995)', '1995-01-01')
# (1401, 'M. Butterfly (1993)', '1993-01-01')
# (1402, 'Ciao, Professore! (1993)', '1993-01-01')
# (1403, 'Caro Diario (Dear Diary) (1994)', '1994-01-01')
# (1404, 'Withnail and I (1987)', '1987-01-01')
# (1405, "Boy's Life 2 (1997)", '1997-03-07')
# (1406, 'When Night Is Falling (1995)', '1995-01-01')
# (1407, 'Specialist, The (1994)', '1994-01-01')
# (1408, 'Gordy (1995)', '1995-01-01')
# (1409, 'Swan Princess, The (1994)', '1994-01-01')
# (1410, 'Harlem (1993)', '1993-01-01')
# (1411, 'Barbarella (1968)', '1968-01-01')
# (1412, 'Land Before Time III: The Time of the Great Giving (1995) (V)', '1995-01-01')
# (1413, 'Street Fighter (1994)', '1994-01-01')
# (1414, 'Coldblooded (1995)', '1995-01-01')
# (1415, 'Next Karate Kid, The (1994)', '1994-01-01')
# (1416, 'No Escape (1994)', '1994-01-01')
# (1417, 'Turning, The (1992)', '1997-05-02')
# (1418, 'Joy Luck Club, The (1993)', '1993-01-01')
# (1419, 'Highlander III: The Sorcerer (1994)', '1994-01-01')
# (1420, "Gilligan's Island: The Movie (1998)", '1997-01-01')
# (1421, 'My Crazy Life (Mi vida loca) (1993)', '1993-01-01')
# (1422, 'Suture (1993)', '1993-01-01')
# (1423, 'Walking Dead, The (1995)', '1995-01-01')
# (1424, 'I Like It Like That (1994)', '1994-01-01')
# (1425, "I'll Do Anything (1994)", '1994-01-01')
# (1426, 'Grace of My Heart (1996)', '1996-09-13')
# (1427, 'Drunks (1995)', '1996-11-01')
# (1428, 'SubUrbia (1997)', '1997-02-07')
# (1429, 'Sliding Doors (1998)', '1998-01-01')
# (1430, 'Ill Gotten Gains (1997)', '1997-01-01')
# (1431, 'Legal Deceit (1997)', '1997-01-01')
# (1432, 'Mighty, The (1998)', '1998-10-09')
# (1433, 'Men of Means (1998)', '1997-01-01')
# (1434, 'Shooting Fish (1997)', '1998-01-16')
# (1435, 'Steal Big, Steal Little (1995)', '1995-01-01')
# (1436, 'Mr. Jones (1993)', '1993-01-01')
# (1437, 'House Party 3 (1994)', '1994-01-01')
# (1438, 'Panther (1995)', '1995-01-01')
# (1439, "Jason's Lyric (1994)", '1994-01-01')
# (1440, 'Above the Rim (1994)', '1994-01-01')
# (1441, 'Moonlight and Valentino (1995)', '1995-01-01')
# (1442, 'Scarlet Letter, The (1995)', '1995-01-01')
# (1443, '8 Seconds (1994)', '1994-01-01')
# (1444, 'That Darn Cat! (1965)', '1965-01-01')
# (1445, 'Ladybird Ladybird (1994)', '1994-01-01')
# (1446, 'Bye Bye, Love (1995)', '1995-01-01')
# (1447, 'Century (1993)', '1993-01-01')
# (1448, 'My Favorite Season (1993)', '1996-04-19')
# (1449, 'Pather Panchali (1955)', '1996-03-22')
# (1450, 'Golden Earrings (1947)', '1947-01-01')
# (1451, 'Foreign Correspondent (1940)', '1940-01-01')
# (1452, 'Lady of Burlesque (1943)', '1943-01-01')
# (1453, 'Angel on My Shoulder (1946)', '1946-01-01')
# (1454, 'Angel and the Badman (1947)', '1947-01-01')
# (1455, 'Outlaw, The (1943)', '1943-01-01')
# (1456, 'Beat the Devil (1954)', '1954-01-01')
# (1457, 'Love Is All There Is (1996)', '1996-10-11')
# (1458, 'Damsel in Distress, A (1937)', '1937-01-01')
# (1459, 'Madame Butterfly (1995)', '1996-09-20')
# (1460, 'Sleepover (1995)', '1996-10-25')
# (1461, 'Here Comes Cookie (1935)', '1935-01-01')
# (1462, 'Thieves (Voleurs, Les) (1996)', '1996-12-25')
# (1463, 'Boys, Les (1997)', '1997-01-01')
# (1464, 'Stars Fell on Henrietta, The (1995)', '1995-01-01')
# (1465, 'Last Summer in the Hamptons (1995)', '1995-01-01')
# (1466, "Margaret's Museum (1995)", '1995-01-01')
# (1467, 'Saint of Fort Washington, The (1993)', '1993-01-01')
# (1468, 'Cure, The (1995)', '1995-01-01')
# (1469, 'Tom and Huck (1995)', '1995-01-01')
# (1470, 'Gumby: The Movie (1995)', '1995-01-01')
# (1471, 'Hideaway (1995)', '1995-01-01')
# (1472, 'Visitors, The (Visiteurs, Les) (1993)', '1996-07-19')
# (1473, 'Little Princess, The (1939)', '1939-01-01')
# (1474, 'Nina Takes a Lover (1994)', '1994-01-01')
# (1475, 'Bhaji on the Beach (1993)', '1993-01-01')
# (1476, 'Raw Deal (1948)', '1948-01-01')
# (1477, 'Nightwatch (1997)', '1997-04-22')
# (1478, 'Dead Presidents (1995)', '1995-01-01')
# (1479, 'Reckless (1995)', '1995-01-01')
# (1480, 'Herbie Rides Again (1974)', '1974-01-01')
# (1481, 'S.F.W. (1994)', '1994-01-01')
# (1482, 'Gate of Heavenly Peace, The (1995)', '1996-05-10')
# (1483, 'Man in the Iron Mask, The (1998)', '1998-03-17')
# (1484, 'Jerky Boys, The (1994)', '1994-01-01')
# (1485, 'Colonel Chabert, Le (1994)', '1994-01-01')
# (1486, 'Girl in the Cadillac (1995)', '1995-01-01')
# (1487, 'Even Cowgirls Get the Blues (1993)', '1993-01-01')
# (1488, 'Germinal (1993)', '1993-01-01')
# (1489, 'Chasers (1994)', '1994-01-01')
# (1490, 'Fausto (1993)', '1993-01-01')
# (1491, 'Tough and Deadly (1995)', '1995-01-01')
# (1492, 'Window to Paris (1994)', '1994-01-01')
# (1493, 'Modern Affair, A (1995)', '1996-09-06')
# (1494, 'Mostro, Il (1994)', '1996-04-19')
# (1495, 'Flirt (1995)', '1996-08-07')
# (1496, 'Carpool (1996)', '1996-08-23')
# (1497, 'Line King: Al Hirschfeld, The (1996)', '1996-10-11')
# (1498, 'Farmer & Chase (1995)', '1997-01-10')
# (1499, 'Grosse Fatigue (1994)', '1994-01-01')
# (1500, 'Santa with Muscles (1996)', '1996-11-08')
# (1501, 'Prisoner of the Mountains (Kavkazsky Plennik) (1996)', '1997-01-31')
# (1502, 'Naked in New York (1994)', '1994-01-01')
# (1503, 'Gold Diggers: The Secret of Bear Mountain (1995)', '1995-01-01')
# (1504, 'Bewegte Mann, Der (1994)', '1996-07-12')
# (1505, 'Killer: A Journal of Murder (1995)', '1996-09-06')
# (1506, 'Nelly & Monsieur Arnaud (1995)', '1996-04-12')
# (1507, 'Three Lives and Only One Death (1996)', '1996-10-11')
# (1508, 'Babysitter, The (1995)', '1995-01-01')
# (1509, 'Getting Even with Dad (1994)', '1994-01-01')
# (1510, 'Mad Dog Time (1996)', '1996-11-08')
# (1511, 'Children of the Revolution (1996)', '1997-05-01')
# (1512, 'World of Apu, The (Apur Sansar) (1959)', '1996-04-05')
# (1513, 'Sprung (1997)', '1997-05-14')
# (1514, 'Dream With the Fishes (1997)', '1997-06-20')
# (1515, 'Wings of Courage (1995)', '1995-01-01')
# (1516, 'Wedding Gift, The (1994)', '1994-01-01')
# (1517, 'Race the Sun (1996)', '1996-01-01')
# (1518, 'Losing Isaiah (1995)', '1995-01-01')
# (1519, 'New Jersey Drive (1995)', '1995-01-01')
# (1520, 'Fear, The (1995)', '1995-01-01')
# (1521, 'Mr. Wonderful (1993)', '1993-01-01')
# (1522, 'Trial by Jury (1994)', '1994-01-01')
# (1523, 'Good Man in Africa, A (1994)', '1994-01-01')
# (1524, 'Kaspar Hauser (1993)', '1996-06-07')
# (1525, 'Object of My Affection, The (1998)', '1998-03-20')
# (1526, 'Witness (1985)', '1985-01-01')
# (1527, 'Senseless (1998)', '1998-01-09')
# (1528, 'Nowhere (1997)', '1997-05-09')
# (1529, 'Underground (1995)', '1996-03-29')
# (1530, 'Jefferson in Paris (1995)', '1995-01-01')
# (1531, 'Far From Home: The Adventures of Yellow Dog (1995)', '1995-01-01')
# (1532, 'Foreign Student (1994)', '1994-01-01')
# (1533, "I Don't Want to Talk About It (De eso no se habla) (1993)", '1993-01-01')
# (1534, 'Twin Town (1997)', '1997-05-30')
# (1535, "Enfer, L' (1994)", '1994-01-01')
# (1536, 'Aiqing wansui (1994)', '1996-07-22')
# (1537, 'Cosi (1996)', '1997-04-11')
# (1538, 'All Over Me (1997)', '1997-04-25')
# (1539, 'Being Human (1993)', '1993-01-01')
# (1540, 'Amazing Panda Adventure, The (1995)', '1995-01-01')
# (1541, 'Beans of Egypt, Maine, The (1994)', '1994-01-01')
# (1542, 'Scarlet Letter, The (1926)', '1926-01-01')
# (1543, 'Johns (1996)', '1996-10-18')
# (1544, 'It Takes Two (1995)', '1995-01-01')
# (1545, 'Frankie Starlight (1995)', '1995-01-01')
# (1546, 'Shadows (Cienie) (1988)', '1988-01-01')
# (1547, 'Show, The (1995)', '1995-01-01')
# (1548, 'The Courtyard (1995)', '1995-01-01')
# (1549, 'Dream Man (1995)', '1995-01-01')
# (1550, 'Destiny Turns on the Radio (1995)', '1995-01-01')
# (1551, 'Glass Shield, The (1994)', '1994-01-01')
# (1552, 'Hunted, The (1995)', '1995-01-01')
# (1553, 'Underneath, The (1995)', '1995-01-01')
# (1554, 'Safe Passage (1994)', '1994-01-01')
# (1555, 'Secret Adventures of Tom Thumb, The (1993)', '1993-01-01')
# (1556, 'Condition Red (1995)', '1995-01-01')
# (1557, 'Yankee Zulu (1994)', '1996-02-16')
# (1558, 'Aparajito (1956)', '1996-03-29')
# (1559, 'Hostile Intentions (1994)', '1994-01-01')
# (1560, 'Clean Slate (Coup de Torchon) (1981)', '1981-01-01')
# (1561, 'Tigrero: A Film That Was Never Made (1994)', '1994-01-01')
# (1562, "Eye of Vichy, The (Oeil de Vichy, L') (1993)", '1993-01-01')
# (1563, 'Promise, The (Versprechen, Das) (1994)', '1994-01-01')
# (1564, 'To Cross the Rubicon (1991)', '1991-01-01')
# (1565, 'Daens (1992)', '1992-01-01')
# (1566, 'Man from Down Under, The (1943)', '1943-01-01')
# (1567, 'Careful (1992)', '1992-01-01')
# (1568, 'Vermont Is For Lovers (1992)', '1992-01-01')
# (1569, 'Vie est belle, La (Life is Rosey) (1987)', '1987-01-01')
# (1570, 'Quartier Mozart (1992)', '1992-01-01')
# (1571, 'Touki Bouki (Journey of the Hyena) (1973)', '1973-01-01')
# (1572, "Wend Kuuni (God's Gift) (1982)", '1982-01-01')
# (1573, 'Spirits of the Dead (Tre passi nel delirio) (1968)', '1968-01-01')
# (1574, "Pharaoh's Army (1995)", '1995-01-01')
# (1575, 'I, Worst of All (Yo, la peor de todas) (1990)', '1990-01-01')
# (1576, 'Hungarian Fairy Tale, A (1987)', '1987-01-01')
# (1577, 'Death in the Garden (Mort en ce jardin, La) (1956)', '1956-01-01')
# (1578, 'Collectionneuse, La (1967)', '1967-01-01')
# (1579, 'Baton Rouge (1988)', '1988-01-01')
# (1580, 'Liebelei (1933)', '1933-01-01')
# (1581, 'Woman in Question, The (1950)', '1950-01-01')
# (1582, 'T-Men (1947)', '1947-01-01')
# (1583, 'Invitation, The (Zaproszenie) (1986)', '1986-01-01')
# (1584, 'Symphonie pastorale, La (1946)', '1946-01-01')
# (1585, 'American Dream (1990)', '1990-01-01')
# (1586, 'Lashou shentan (1992)', '1992-01-01')
# (1587, 'Terror in a Texas Town (1958)', '1958-01-01')
# (1588, 'Salut cousin! (1996)', '1997-02-21')
# (1589, 'Schizopolis (1996)', '1997-05-23')
# (1590, 'To Have, or Not (1995)', '1997-06-06')
# (1591, 'Duoluo tianshi (1995)', '1998-01-21')
# (1592, 'Magic Hour, The (1998)', '1998-01-30')
# (1593, 'Death in Brunswick (1991)', '1996-08-16')
# (1594, 'Everest (1998)', '1998-03-10')
# (1595, 'Shopping (1994)', '1996-02-09')
# (1596, 'Nemesis 2: Nebula (1995)', '1995-01-01')
# (1597, 'Romper Stomper (1992)', '1992-01-01')
# (1598, 'City of Industry (1997)', '1997-03-14')
# (1599, "Someone Else's America (1995)", '1996-05-10')
# (1600, 'Guantanamera (1994)', '1997-05-16')
# (1601, 'Office Killer (1997)', '1997-01-01')
# (1602, 'Price Above Rubies, A (1998)', '1998-03-20')
# (1603, 'Angela (1995)', '1996-02-16')
# (1604, 'He Walked by Night (1948)', '1948-01-01')
# (1605, 'Love Serenade (1996)', '1997-07-11')
# (1606, 'Deceiver (1997)', '1997-01-01')
# (1607, 'Hurricane Streets (1998)', '1998-01-01')
# (1608, 'Buddy (1997)', '1997-06-06')
# (1609, 'B*A*P*S (1997)', '1997-03-28')
# (1610, 'Truth or Consequences, N.M. (1997)', '1997-05-02')
# (1611, 'Intimate Relations (1996)', '1997-05-09')
# (1612, 'Leading Man, The (1996)', '1998-01-16')
# (1613, 'Tokyo Fist (1995)', '1998-02-11')
# (1614, 'Reluctant Debutante, The (1958)', '1958-01-01')
# (1615, 'Warriors of Virtue (1997)', '1997-05-02')
# (1616, 'Desert Winds (1995)', '1995-01-01')
# (1617, 'Hugo Pool (1997)', '1997-01-01')
# (1618, 'King of New York (1990)', '1990-01-01')
# (1619, 'All Things Fair (1996)', '1996-03-08')
# (1620, 'Sixth Man, The (1997)', '1997-03-28')
# (1621, 'Butterfly Kiss (1995)', '1996-04-26')
# (1622, 'Paris, France (1993)', '1993-01-01')
# (1623, 'Cйrйmonie, La (1995)', '1996-12-20')
# (1624, 'Hush (1998)', '1998-03-10')
# (1625, 'Nightwatch (1997)', '1997-04-22')
# (1626, 'Nobody Loves Me (Keiner liebt mich) (1994)', '1996-02-09')
# (1627, 'Wife, The (1995)', '1996-07-26')
# (1628, 'Lamerica (1994)', '1994-01-01')
# (1629, 'Nico Icon (1995)', '1995-01-01')
# (1630, 'Silence of the Palace, The (Saimt el Qusur) (1994)', '1996-02-02')
# (1631, 'Slingshot, The (1993)', '1993-01-01')
# (1632, 'Land and Freedom (Tierra y libertad) (1995)', '1996-03-29')
# (1633, 'Б kцldum klaka (Cold Fever) (1994)', '1996-03-08')
# (1634, 'Etz Hadomim Tafus (Under the Domin Tree) (1994)', '1996-04-19')
# (1635, 'Two Friends (1986) ', '1986-04-26')
# (1636, 'Brothers in Trouble (1995)', '1996-04-26')
# (1637, 'Girls Town (1996)', '1996-08-23')
# (1638, 'Normal Life (1996)', '1996-10-25')
# (1639, 'Bitter Sugar (Azucar Amargo) (1996)', '1996-11-22')
# (1640, 'Eighth Day, The (1996)', '1996-11-01')
# (1641, 'Dadetown (1995)', '1996-09-18')
# (1642, "Some Mother's Son (1996)", '1996-12-27')
# (1643, 'Angel Baby (1995)', '1997-01-10')
# (1644, 'Sudden Manhattan (1996)', '1997-06-13')
# (1645, 'Butcher Boy, The (1998)', '1998-01-01')
# (1646, 'Men With Guns (1997)', '1998-03-06')
# (1647, 'Hana-bi (1997)', '1998-03-20')
# (1648, 'Niagara, Niagara (1997)', '1998-03-20')
# (1649, 'Big One, The (1997)', '1998-03-27')
# (1650, 'Butcher Boy, The (1998)', '1998-01-01')
# (1651, 'Spanish Prisoner, The (1997)', '1998-03-27')
# (1652, 'Temptress Moon (Feng Yue) (1996)', '1997-06-13')
# (1653, 'Entertaining Angels: The Dorothy Day Story (1996)', '1996-09-27')
# (1654, 'Chairman of the Board (1998)', '1998-01-01')
# (1655, 'Favor, The (1994)', '1994-01-01')
# (1656, 'Little City (1998)', '1998-02-20')
# (1657, 'Target (1995)', '1996-02-28')
# (1658, 'Substance of Fire, The (1996)', '1996-12-06')
# (1659, 'Getting Away With Murder (1996)', '1996-04-12')
# (1660, 'Small Faces (1995)', '1996-08-09')
# (1661, 'New Age, The (1994)', '1994-01-01')
# (1662, 'Rough Magic (1995)', '1997-05-30')
# (1663, 'Nothing Personal (1995)', '1997-04-30')
# (1664, '8 Heads in a Duffel Bag (1997)', '1997-04-18')
# (1665, "Brother's Kiss, A (1997)", '1997-04-25')
# (1666, 'Ripe (1996)', '1997-05-02')
# (1667, 'Next Step, The (1995)', '1997-06-13')
# (1668, 'Wedding Bell Blues (1996)', '1997-06-13')
# (1669, 'MURDER and murder (1996)', '1997-06-20')
# (1670, 'Tainted (1998)', '1998-02-01')
# (1671, 'Further Gesture, A (1996)', '1998-02-20')
# (1672, 'Kika (1993)', '1993-01-01')
# (1673, 'Mirage (1995)', '1995-01-01')
# (1674, 'Mamma Roma (1962)', '1962-01-01')
# (1675, 'Sunchaser, The (1996)', '1996-10-25')
# (1676, 'War at Home, The (1996)', '1996-01-01')
# (1677, 'Sweet Nothing (1995)', '1996-09-20')
# (1678, "Mat' i syn (1997)", '1998-02-06')
# (1679, 'B. Monkey (1998)', '1998-02-06')
# (1680, 'Sliding Doors (1998)', '1998-01-01')
# (1681, 'You So Crazy (1994)', '1994-01-01')
# (1682, 'Scream of Stone (Schrei aus Stein) (1991)', '1996-03-08')

# %%
df_movies = pd.read_sql_query("SELECT * from Movies;", con)

# verify that result of SQL query is stored in the dataframe
print(df_movies.head())

#Be sure to close the connection.
con.close()
# Out:
#    id              title release_date
# 0   1   Toy Story (1995)   1995-01-01
# 1   2   GoldenEye (1995)   1995-01-01
# 2   3  Four Rooms (1995)   1995-01-01
# 3   4  Get Shorty (1995)   1995-01-01
# 4   5     Copycat (1995)   1995-01-01

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1682 entries, 0 to 1681
# Data columns (total 3 columns):
# id              1682 non-null int64
# title           1682 non-null object
# release_date    1681 non-null object
# dtypes: int64(1), object(2)
# memory usage: 52.6+ KB

# %% [markdown]
# The output tells a few things about our DataFrame.
# Each row was assigned an index of 0 to N-1, where N is the number of rows in the DataFrame. pandas will do this by default if an index is not specified. Don't worry, this can be changed later.
# There are 1,682 rows (every row must have an index).
# Our dataset has five total columns, one of which isn't populated at all (video_release_date) and two that are missing some values (release_date and imdb_url).
# The last line displays the datatypes of each column, but not necessarily in the corresponding order to the listed columns.
# You should use the dtypes method to get the datatype for each column.

# %%
df_movies.dtypes
# Out:
# id               int64
# title           object
# release_date    object
# dtype: object

# %% [markdown]
# Benchmarking our results
# http://sebastianraschka.com/Articles/sqlite3_database.html#benchmarks

# %% [markdown]
# Where clause examples
#
# towed[towed["state"] == "TX"] # all columns and records where the car was from TX
#
# towed[(towed["state"] == "TX") & (towed["make"] == "KIA")] # made by KIA AND from TX
#
# towed[(towed["state"] == "MA") | (towed["make"] == "JAGU")] # made by Jaguar OR from MA
#
# towed[towed["make"] == "KIA"].sort("color") # made by KIA, ordered by color (A to Z)
