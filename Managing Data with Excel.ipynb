# %%
# fn = r'C:\Users\Sterling7\Dropbox\dave45678\Managing Data with Excel.csv'
fn = 'Managing Data with Excel.csv'
from pandas import DataFrame, read_csv
import pandas as pd

#read_csv takes an encoding option to deal with files in different formats. 
#I mostly use `read_csv('file', encoding = "ISO-8859-1"), or 
#alternatively encoding = utf8 for reading, and generally utf-8 for to_csv.
df = pd.read_csv(fn, encoding = "ISO-8859-1")# or encoding
sorted = df.sort(['ZipCode'],ascending=True)
sorted.head(50)
#fix zip code
#count of unique zip codes
df.groupby(['City','State'])['ZipCode'].nunique().reset_index()

#find and remove duplicates
#get counts by state, position, company
df[df['State'].isin(['MD', 'DC','VA'])]
df
#add column for salary, use random number
#get max and min salary
#get top 10 records with high salary
#return only the records for some criteria, ie... State = 'CA' or Position = 'xyz'
#return records with no postition value
#fill in missing data in position
#import another xls and merge the two... ie.... a list of email addresses or positions and link by name
# Out:
# /Users/sterlingbusinessadvantage/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:10: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                   FullName Title  FirstName    LastName  \
# 0            Everett Aaron   Mr.    Everett       Aaron
# 1             Karen Abadie  Mrs.      Karen      Abadie
# 2             Lorena Abbas  Mrs.     Lorena       Abbas
# 3            Bettye Abbott  Mrs.     Bettye      Abbott
# 4          Danielle Abbott  Mrs.   Danielle      Abbott
# 5            George Abbott   Mr.     George      Abbott
# 6             Helen Abbott  Mrs.      Helen      Abbott
# 7              John Abbott   Mr.       John      Abbott
# 8              Jose Abbott   Mr.       Jose      Abbott
# 9             Julie Abbott   Ms.      Julie      Abbott
# 10            Marie Abbott  Mrs.      Marie      Abbott
# 11             Mary Abbott   Ms.       Mary      Abbott
# 12           Milton Abbott   Mr.     Milton      Abbott
# ...
